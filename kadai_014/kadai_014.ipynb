# %%
user_name = "侍花子"

def show_user_name():

    user_name = "侍太郎"
    print(user_name)

show_user_name()
user_name
# Out:
# 侍太郎
# '侍花子'

# %%
price1 = 100
price2 = 200
tax = 1.1

def total():
    t = price1 + price2
    return t

print(total() * tax)
# Out:
# 330.0
