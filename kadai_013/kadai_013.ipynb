# %%
def calculate_total(price):

    total = price + 500
    print(f"{total}円")
    # return total          # コメントアウトはCtrl+/ボタンで共通

calculate_total(1200)
sum_price = calculate_total(1200)
type(sum_price), sum_price
# Out:
# 1700円

# %%
def cal_tax(price, tax):

    result = price * (tax / 100) + price
    return result

cal_tax(110, 10)
# Out:
# 121.0
