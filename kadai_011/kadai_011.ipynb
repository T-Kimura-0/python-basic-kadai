# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]
num = 0

#len関数は指定された配列の数を読み出す
length = len(array)

while num < length:
    print(array[num])
    num = num + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

for planet in array:
    print(planet)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]


for planet in array:
    print(planet)

num = 0

#len関数は指定された配列の数を読み出す
length = len(array)

while num < length:
    print(array[num])
    num = num + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
